# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('covid_vaccine_statewise.csv')

# %%
df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
df.rename(columns={'Updated On' : 'VaccineDate'},inplace=True)

# %%
df.head()
# Out:
#   VaccineDate  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
df.isnull().sum()
# Out:
# VaccineDate                               0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
df=df.drop(columns=['Sputnik V (Doses Administered)','AEFI','18-44 Years (Doses Administered)','45-60 Years (Doses Administered)','60+ Years (Doses Administered)'],axis=1)

# %%
df
# Out:
#      VaccineDate        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df.isnull().sum()
# Out:
# VaccineDate                               0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# Female(Individuals Vaccinated)         7685
# Transgender(Individuals Vaccinated)    7685
# Total Individuals Vaccinated           1926
# dtype: int64

# %%
perc = 75.0 # Here N is 75
min_count =  int(((100-perc)/100)*df.shape[1] + 1)
mod_df = df.dropna( axis=0, 
                    thresh=min_count)

# %%
mod_df.tail()
# Out:
#      VaccineDate        State  Total Doses Administered   Sessions   Sites   \
# 7834  05/08/2021  West Bengal                31371174.0  1018095.0   2604.0
# 7835  06/08/2021  West Bengal                31774086.0   930084.0   2485.0
# 7836  07/08/2021  West Bengal                32029325.0   727057.0   1833.0
# 7837  08/08/2021  West Bengal                32098768.0   271684.0    584.0
# 7838  09/08/2021  West Bengal                32390378.0   866173.0   2086.0
#
#       First Dose Administered  Second Dose Administered  \
# 7834               22401043.0                 8970131.0
# 7835               22745949.0                 9028137.0
# 7836               22959053.0                 9070272.0
# 7837               23017864.0                 9080904.0
# 7838               23257417.0                 9132961.0
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 7834                 16767671.0                   14598799.0
# ...

# %%
mod_df.isnull().sum()
# Out:
# VaccineDate                               0
# State                                     0
# Total Doses Administered                  0
# Sessions                                  0
#  Sites                                    0
# First Dose Administered                   0
# Second Dose Administered                  0
# Male (Doses Administered)               160
# Female (Doses Administered)             160
# Transgender (Doses Administered)        160
#  Covaxin (Doses Administered)             0
# CoviShield (Doses Administered)           0
# 18-44 Years(Individuals Vaccinated)    3888
# 45-60 Years(Individuals Vaccinated)    3887
# 60+ Years(Individuals Vaccinated)      3887
# Male(Individuals Vaccinated)           7461
# Female(Individuals Vaccinated)         7461
# Transgender(Individuals Vaccinated)    7461
# Total Individuals Vaccinated           1702
# dtype: int64

# %%
perc = 80.0 # Here N is 75
min_count =  int(((100-perc)/100)*df.shape[0] + 1)
data = mod_df.dropna( axis=1, 
                    thresh=min_count)

# %%
data.isnull().sum()
# Out:
# VaccineDate                               0
# State                                     0
# Total Doses Administered                  0
# Sessions                                  0
#  Sites                                    0
# First Dose Administered                   0
# Second Dose Administered                  0
# Male (Doses Administered)               160
# Female (Doses Administered)             160
# Transgender (Doses Administered)        160
#  Covaxin (Doses Administered)             0
# CoviShield (Doses Administered)           0
# 18-44 Years(Individuals Vaccinated)    3888
# 45-60 Years(Individuals Vaccinated)    3887
# 60+ Years(Individuals Vaccinated)      3887
# Total Individuals Vaccinated           1702
# dtype: int64

# %%
data.head()
# Out:
#   VaccineDate  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
data=data[data.State!='India']

# %%
data.isnull().sum()
# Out:
# VaccineDate                               0
# State                                     0
# Total Doses Administered                  0
# Sessions                                  0
#  Sites                                    0
# First Dose Administered                   0
# Second Dose Administered                  0
# Male (Doses Administered)                 0
# Female (Doses Administered)               0
# Transgender (Doses Administered)          0
#  Covaxin (Doses Administered)             0
# CoviShield (Doses Administered)           0
# 18-44 Years(Individuals Vaccinated)    3783
# 45-60 Years(Individuals Vaccinated)    3782
# 60+ Years(Individuals Vaccinated)      3782
# Total Individuals Vaccinated           1656
# dtype: int64

# %%
data
# Out:
#      VaccineDate                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
# ...          ...                          ...                       ...
# 7834  05/08/2021                  West Bengal                31371174.0
# 7835  06/08/2021                  West Bengal                31774086.0
# 7836  07/08/2021                  West Bengal                32029325.0
# 7837  08/08/2021                  West Bengal                32098768.0
# 7838  09/08/2021                  West Bengal                32390378.0
#
#        Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
data=data.fillna(0)

# %%
data
# Out:
#      VaccineDate                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
# ...          ...                          ...                       ...
# 7834  05/08/2021                  West Bengal                31371174.0
# 7835  06/08/2021                  West Bengal                31774086.0
# 7836  07/08/2021                  West Bengal                32029325.0
# 7837  08/08/2021                  West Bengal                32098768.0
# 7838  09/08/2021                  West Bengal                32390378.0
#
#        Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
data['VaccineDate'] = pd. to_datetime(data['VaccineDate'],format='%d/%m/%Y')
data['year'] = pd. DatetimeIndex(data['VaccineDate']). year
data['month'] = pd. DatetimeIndex(data['VaccineDate']). month

# %%
data.head()
# Out:
#     VaccineDate                        State  Total Doses Administered  \
# 212  2021-01-16  Andaman and Nicobar Islands                      23.0
# 213  2021-01-17  Andaman and Nicobar Islands                      23.0
# 214  2021-01-18  Andaman and Nicobar Islands                      42.0
# 215  2021-01-19  Andaman and Nicobar Islands                      89.0
# 216  2021-01-20  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 212       2.0      2.0                     23.0                       0.0
# 213       2.0      2.0                     23.0                       0.0
# 214       9.0      2.0                     42.0                       0.0
# 215      12.0      2.0                     89.0                       0.0
# 216      16.0      3.0                    124.0                       0.0
#
#      Male (Doses Administered)  Female (Doses Administered)  \
# ...

# %%
d={1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
data.month=data.month.map(d)

# %%
data.head()
# Out:
#     VaccineDate                        State  Total Doses Administered  \
# 212  2021-01-16  Andaman and Nicobar Islands                      23.0
# 213  2021-01-17  Andaman and Nicobar Islands                      23.0
# 214  2021-01-18  Andaman and Nicobar Islands                      42.0
# 215  2021-01-19  Andaman and Nicobar Islands                      89.0
# 216  2021-01-20  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 212       2.0      2.0                     23.0                       0.0
# 213       2.0      2.0                     23.0                       0.0
# 214       9.0      2.0                     42.0                       0.0
# 215      12.0      2.0                     89.0                       0.0
# 216      16.0      3.0                    124.0                       0.0
#
#      Male (Doses Administered)  Female (Doses Administered)  \
# ...

# %%
data.to_excel('vaccination.xlsx', index=False)
